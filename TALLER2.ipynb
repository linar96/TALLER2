# %% [markdown]
# TALLER 2  PYTHON

# %% [markdown]
# LINA ROCIO CARDENAS FERNANDEZ
# GRUPO 2

# %% [markdown]
# 1. Numeros palíndromos:
# Escriba una función que reciba un numero entero (positivo) o un String y entregue como respuesta si la entrada es o no un palíndromo.

# %%
#RES 1 

pali=str.casefold(input("Ingrese dato a consultar: "))
def num_p():
  
    var=pali.split(' ')
    vari=''.join(var)
    rev=vari[::-1]
    if  (vari ==rev):
       print("El dato '{}' digitado es palíndromo".format(pali))
    else:
       print("El dato digitado no es palíndromo") 
print(num_p())
# Out:
# Ingrese dato a consultar: 232
# El dato '232' digitado es palíndromo
# None

# %%
#RES 2
pali=str(input("Ingrese dato a consultar: "))
def num_p():
  v=pali.casefold()
  var=v[::-1]
  c=""
  for i in var:
    c=c+i

  if  (pali ==c):
      print("El dato '{}' digitado es palíndromo".format(pali))
  else:
      print("El dato digitado no es palíndromo") 
print(num_p())
# Out:
# Ingrese dato a consultar: 232
# El dato '232' digitado es palíndromo
# None

# %%
#RES 3
pali=str(input("Ingrese dato a consultar: "))
def num_p():
  v=pali.casefold()
  var=reversed(v)

  if  (list(v) ==list(var)):
    print("El dato '{}' digitado es palíndromo".format(pali))
  else:
    print("El dato digitado no es palíndromo") 
print(num_p())
# Out:
# Ingrese dato a consultar: 232
# El dato '232' digitado es palíndromo
# None

# %%
#RES 4 somo permite consultar datos numerico
pali=input("Ingrese dato a consultar: ")
def num_p():
  try:
   v=int(pali.casefold())
     
   if  pali ==str(pali)[::-1]:
    print("El dato '{}' digitado es palíndromo".format(pali))
   else:
    print("El dato digitado no es palíndromo") 
  except ValueError:
      print("Error porfavor verifique que el dato digitado sea numerico") 
print(num_p())
# Out:
# Ingrese dato a consultar: 232
# El dato '232' digitado es palíndromo
# None

# %% [markdown]
# 2. Numeros primos:
# Escriba una función que reciba como entrada un número y determine si es o no un numero primo.

# %%
#RES 1
p=int(input("Ingrese numero a consultar: "))

def num_p(num):
   c=0
   for i in range(1, num+1):
     if num % i==0:
        c += 1
   if c== 2:
      print("El numero digitado es primo") 
   else:
       print("El numero digitado no es primo")   
print(num_p(p))
# Out:
# Ingrese numero a consultar: 3
# El numero digitado es primo
# None

# %%
#RES 2
p=int(input("Ingrese numero a consultar: "))

def num_p(num):
   if num<2:
     print("El numero digitado no es primo")
   for i in range(2, num):
         if num % i==0:
            print("El numero digitado no es primo")
   print("El numero digitado es primo") 
  
      
print(num_p(p))
# Out:
# Ingrese numero a consultar: 3
# El numero digitado es primo
# None

# %% [markdown]
# 3. Numeros primos 2:
# Escriba una función que devuelva una lista de numeros primos con base a la cantidad que el usuario le solicite, Ejemplo si el usuario ingresa 3 debe retornar los 3 primeros numeros primos.

# %%
nump=int(input("Ingrese la cantidad de primos que desea obtener : "))
def primo():
  numero=2
  yield numero
  while True:
    num = numero
    while True:
      num +=1
      con=1
      condiv=0

      while con<=num:
         if num % con ==0:
            condiv +=1
         if condiv >2:
            break
         con +=1
      if condiv ==2:
         yield num 
  
num_primo=primo()
lpri=[next(num_primo) for _ in range(nump)]
print(lpri)
# Out:
# Ingrese la cantidad de primos que desea obtener : 3
# [2, 3, 5]

# %% [markdown]
# 4. Numeros primos 3:
# El primo de Mersenne es un numero primo de la forma 2𝑝−1, una de las propiedades de los primos de Mersenne es que p debe ser también un número primo, escriba una función que imprima la cantidad de numeros que el usuario solicite, Ejemplo: si el usuario ingreso 3 los primeros primos de Mersenne deberían ser 3, 7 y 31.

# %%
nump=int(input("Ingrese la cantidad de primos de mersenne que desea obtener: "))
def primo():
  mer =0
  num=1
  while True:
    while True:
      num +=1
      con=1
      condiv=0

      while con<=num:
         if num % con ==0:
            mer=int(2**num)-1
            condiv +=1
         if condiv >2:
            break
         con +=1
      if condiv ==2:
         yield mer 
    

num_primo=primo()
lpri=[next(num_primo) for _ in range(nump)]
print(lpri)
# Out:
# Ingrese la cantidad de primos de mersenne que desea obtener: 3
# [3, 7, 31]

# %%
num=2
mer=2**num -1
print(mer)
# Out:
# 3

# %% [markdown]
# 5. Máximo común divisor:
# Escriba una función que reciba dos numeros y retorne el cálculo de su máximo común divisor.

# %%
n1=int(input("Ingrese el primer numero: "))
n2=int(input("Ingrese el segundo numero: "))
def maxd(x,y):
   if x<y:
     return maxd(y,x)
   while y !=0:
     x,y =y,x % y
   print("el maximo comun divisor de los numeros digitado es:" + str(x))
print (maxd(n1,n2))
# Out:
# Ingrese el primer numero: 4
# Ingrese el segundo numero: 5
# el maximo comun divisor de los numeros digitado es:1
# None

# %% [markdown]
# 6.  Numeros romanos:
# Escriba una función que reciba un numero y retorne como resultado el numero romano de dicho número.

# %%
n=int(input("Ingrese el numero a convertir: "))
num_map = [(1000, 'M'), (900, 'CM'), (500, 'D'), (400, 'CD'), (100, 'C'), (90, 'XC'),
           (50, 'L'), (40, 'XL'), (10, 'X'), (9, 'IX'), (5, 'V'), (4, 'IV'), (1, 'I')]


def conv(num):

    roman = ''

    while num > 0:
        for i, r in num_map:
            while num >= i:
                roman += r
                num -= i

    return roman
print(conv(n))
# Out:
# Ingrese el numero a convertir: 212
# CCXII
